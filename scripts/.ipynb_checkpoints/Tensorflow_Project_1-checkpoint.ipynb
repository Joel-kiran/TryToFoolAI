# %%
import tensorflow as tf
import os
import numpy as np

training_data_damaged = []
training_data_undamaged = []
for n in os.listdir('../preprocessed_data/training/damaged/'):
    training_data_damaged.append("../preprocessed_data/training/damaged/"+n)
for n in os.listdir('../preprocessed_data/training/undamaged/'):
    training_data_undamaged.append('../preprocessed_data/training/undamaged/'+n)
    
#print(training_data_damaged[:10])
#print(training_data_undamaged[:10])

training_data=training_data_damaged+training_data_undamaged
print(training_data[:10])

training_data_label = []
for i in training_data_damaged:
    training_data_label.append(1)
for i in training_data_undamaged:
    training_data_label.append(0)

print(len(training_data), len(training_data_label))

filenames = tf.constant(training_data)
labels = tf.constant(training_data_label)


img_raw = tf.io.read_file(filenames[0])
img_tensor = tf.image.decode_image(img_raw)

#print(img_tensor.shape)
#print(img_tensor.dtype)
img_final = tf.image.resize(img_tensor, [192, 192])
img_final = img_final/255.0
#print(img_final.shape)
#print(img_final.numpy().min())
#print(img_final.numpy().max())

def preprocess_image(image):
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [192, 192])
    image /= 255.0  # normalize to [0,1] range

    return image

def load_and_preprocess_image(path):
    img = tf.io.read_file(path)
    return preprocess_image(img)

def return_labels(label):
    print("hil")
    return label

print(np.array(training_data_label))
path_ds = tf.data.Dataset.from_tensor_slices(training_data)

image_ds = path_ds.map(load_and_preprocess_image)
label_ds = tf.data.Dataset.from_tensor_slices(np.array(training_data_label))
#labels = label_ds.map(label_ds)
#print(image_ds)
print(label_ds)
#image_label_ds = tf.data.Dataset.zip((image_ds, label_ds))
'''
iterator =  tf.compat.v1.data.Iterator.from_structure(tf.compat.v1.data.get_output_types(image_label_ds),
                                           tf.compat.v1.data.get_output_shapes(image_label_ds))
train_init_op = iterator.make_initializer(image_label_ds)
train_dataset = image_label_ds.take(1000)
test_dataset = image_label_ds.skip(1000) 
#next_element = iterator.get_next()
print(train_dataset)
'''
# Out:
# ['../preprocessed_data/training/damaged/0804.JPEG', '../preprocessed_data/training/damaged/0107.JPEG', '../preprocessed_data/training/damaged/0557.JPEG', '../preprocessed_data/training/damaged/0042.JPEG', '../preprocessed_data/training/damaged/0412.jpeg', '../preprocessed_data/training/damaged/0691.JPEG', '../preprocessed_data/training/damaged/0384.JPEG', '../preprocessed_data/training/damaged/0500.JPEG', '../preprocessed_data/training/damaged/0150.JPEG', '../preprocessed_data/training/damaged/0853.JPEG']
# 1840 1840
# [1 1 1 ... 0 0 0]
# <TensorSliceDataset shapes: (), types: tf.int64>
# ...

# %%
features, labels = next(iter(train_dataset))
num_classes = 2
'''
#Conv2D(filters=64, kernel_size=1, input_shape=(10,10,3))
model = tf.keras.Sequential([
  tf.keras.layers.Conv2D(filters=64, kernel_size=1, input_shape=(192,192,3)),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

model.fit(
  features,
  epochs=3
)
'''

feature, label = next(iter(train_dataset))
#print(features[:102], len(labels))

from tensorflow.keras.layers import Conv2D, Flatten, Dense,MaxPooling2D
model=tf.keras.models.Sequential()
model.add(Conv2D(16, (3,3), padding='same', input_shape=(192,192,3)))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(128))
model.add(Dense(2))
model.summary()

model.compile(optimizer='adam', loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])
model.fit(image_ds, epochs=3)
#loss = tf.reduce_sum(tf.square(y - y_data))
#optimizer = tf.train.AdamOptimizer().minimize(loss)
# get accuracy
#prediction = tf.argmax(logits, 1)
#equality = tf.equal(prediction, tf.argmax(next_element[1], 1))
#accuracy = tf.reduce_mean(tf.cast(equality, tf.float32))
#init_op = tf.global_variables_initializer()
'''
epochs = 600
with tf.Session() as sess:
    sess.run(model)
    sess.run(iterator)
    for i in range(epochs):
        l, _, acc = sess.run()
        if i % 50 == 0:
            print("Epoch: {}, loss: {:.3f}, training accuracy: {:.2f}%".format(i, l, acc * 100))

'''
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/t1/bvs3thn144vgkyf7lpstqsb40000gn/T/ipykernel_45675/20778908.py in <module>
#      32 model=tf.keras.models.Sequential()
#      33 model.add(Conv2D(16, (3,3), padding='same', input_shape=(192,192,3, 1000)))
# ---> 34 model.add(MaxPooling2D())
#      35 model.add(Flatten())
#      36 model.add(Dense(128))
#
# ~/miniforge3/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     528     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     529     try:
# --> 530       result = method(self, *args, **kwargs)
#     531     finally:
#     532       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~/miniforge3/lib/python3.9/site-packages/keras/engine/sequential.py in add(self, layer)
# ...

# %%
# step 2: create a dataset returning slices of `filenames`
dataset = tf.data.Dataset.from_tensor_slices((filenames, labels))
print(dataset)

# step 3: parse every image in the dataset using `map`
def _parse_function(filename, label):
    image_string = tf.io.read_file(filename)
    print(image_string)
    image_decoded = tf.image.decode_jpeg(image_string, channels=3)
    image = tf.cast(image_decoded, tf.float32)
    return image, label

dataset = dataset.map(_parse_function)
#dataset = dataset.batch(2)
print(dataset)
# Out:
# ['../data/training/damaged/0804.JPEG', '../data/training/damaged/0107.JPEG', '../data/training/damaged/0557.JPEG', '../data/training/damaged/0042.JPEG', '../data/training/damaged/0412.jpeg', '../data/training/damaged/0691.JPEG', '../data/training/damaged/0384.JPEG', '../data/training/damaged/0500.JPEG', '../data/training/damaged/0150.JPEG', '../data/training/damaged/0853.JPEG']
# <TensorSliceDataset shapes: ((), ()), types: (tf.string, tf.int32)>
# Tensor("ReadFile:0", shape=(), dtype=string)
# <MapDataset shapes: ((None, None, 3), ()), types: (tf.float32, tf.int32)>
